# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexV2291/Jupyter/blob/develop/Third.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Третий файл

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$

# %%
a = 3
b = 6
if a ==b:
    print("Переменные равны")
elif a > b:
    print("a больше b")
elif a < b:
    print("a меньше b")
else:
    print("Не должно быть напечатано")
print("")

a = int(input("Введите число А: "))
b = 3
print(('не делится', 'делится')[a // b * b == a])
print("")

a=int(input("Введите число А: "))
b=3
if a%b == 0:
    print("делится")
else:
    print("не делится")
print("")

a = True
b = True
a = False
if a and b:
    print("a и b")
elif a or b:
    print("Один из a или b")
else:
    print("Ничего")
# Out:
# a меньше b
#
# Введите число А: 4
# не делится
#
# Введите число А: 2
# не делится
#
# Один из a или b
